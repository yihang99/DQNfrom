# %%
import csv

with open('single_dqn.csv','r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    avg_episode_rewards = [float(row[2]) for row in reader]
    print(avg_episode_rewards)

with open('single_dqn.csv','r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    avg_truncated_episode_rewards = [float(row[1]) for row in reader]
    print(avg_truncated_episode_rewards)
# Out:
# [0.0, 200.0, 176.25, 166.75, 187.25, 141.75, 217.25, 116.0, 176.25, 159.5, 213.5, 251.75, 201.5, 248.75, 276.5, 292.25, 257.5, 257.75, 330.75, 299.5, 287.75, 358.75, 360.5, 318.25, 318.0, 298.0, 393.0, 340.25, 370.5, 442.75, 387.25, 357.75, 383.75, 295.75, 399.5, 391.75, 443.5, 487.0, 391.0, 387.25, 346.75, 407.5, 408.5, 387.25, 429.25, 394.0, 448.0, 410.0, 400.75, 456.5, 489.75, 481.5, 438.5, 410.25, 332.75, 408.5, 479.5, 477.0, 394.75, 360.5]
# [0.0, 12.8, 12.0, 9.7, 13.05, 10.9, 11.55, 9.2, 12.55, 10.65, 13.4, 16.05, 13.95, 16.8, 16.7, 19.15, 18.35, 18.9, 21.75, 19.05, 19.0, 22.9, 23.45, 21.35, 21.4, 19.4, 24.1, 21.75, 23.35, 26.6, 24.0, 22.65, 24.85, 20.7, 25.3, 25.65, 27.85, 29.7, 25.6, 24.25, 24.15, 26.0, 25.8, 24.4, 25.65, 25.65, 27.05, 27.05, 25.7, 28.15, 29.75, 29.75, 28.4, 26.75, 22.65, 25.95, 28.65, 29.65, 25.7, 23.75]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.ylabel('average truncated episode rewards')
plt.plot(avg_truncated_episode_rewards, label='avg_truncated_episode_rewards')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.ylabel('average episode rewards')
plt.plot(avg_episode_rewards, label='avg_episode_rewards')
